# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
list_device_url ="https://makesens.aws.thinger.io/v1/users/MakeSens/devices"
list_device_headers = {'Content-Type': 'application/json', 'Authorization':  'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJUb2tlbl9QYXNvZWNvIiwic3ZyIjoibWFrZXNlbnMuYXdzLnRoaW5nZXIuaW8iLCJ1c3IiOiJNYWtlU2VucyJ9.MRZqkj8fnqXkzqf_EefhzXVQ6FYnL4iyNX-GraCKuhU'}

# %%
s = requests.get(list_device_url, headers = list_device_headers)
devices_json = json.dumps(s.json())
pd.read_json(devices_json, typ = 'frame', dtype = 'dict')
# Out:
#           asset_group                              connection  \
# 0       ICP_Ambiental   {'active': True, 'ts': 1651674576605}
# 1       ICP_Ambiental   {'active': True, 'ts': 1651674570500}
# 2                       {'active': True, 'ts': 1651674563817}
# 3       ICP_Ambiental   {'active': True, 'ts': 1651674540231}
# 4    Grupo_Halley_CO2   {'active': True, 'ts': 1651674536079}
# 5             LaCoNGA   {'active': True, 'ts': 1651674516884}
# 6             LaCoNGA   {'active': True, 'ts': 1651660356152}
# 7                 NaN   {'active': True, 'ts': 1651613176992}
# 8             PasoEco   {'active': True, 'ts': 1651610758641}
# 9                 NaN   {'active': True, 'ts': 1651575269615}
# 10                NaN   {'active': True, 'ts': 1651536024296}
# 11                NaN   {'active': True, 'ts': 1651241257304}
# 12            LaCoNGA   {'active': True, 'ts': 1650577841984}
# 13      ICP_Ambiental  {'active': False, 'ts': 1651674555094}
# ...
